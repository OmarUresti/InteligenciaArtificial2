# %% [markdown]
# ![Python_logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
#
#
#    # **Cortex Game: Round1--Amount**

# %% [markdown]
# > Before playing the game, you need to connect to SASPy first.
# >
# >> If it is your first time, please follow the 4 steps mentioned below!

# %% [markdown]
# ***
# ## **Connect to SASPy**

# %% [markdown]
# **0- Connect to your Google Drive folder**

# %%
my_folder = "/content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS"

from google.colab import drive
drive.mount('/content/drive')

# Change the following code to set your Drive folder
import os
os.chdir(my_folder)
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS

# %% [markdown]
# **1- Make sure that your Python version is 3.3 or higher as well as your Java version is 1.8.0_162 or higher**

# %%
# !echo "Python is at" $(which python)
# !python --version
# Out:
# Python is at /usr/local/bin/python
# Python 3.7.15

# %%
# !echo "Java is at" $(which java)
# !/usr/bin/java -version
# Out:
# Java is at /usr/bin/java
# openjdk version "11.0.17" 2022-10-18
# OpenJDK Runtime Environment (build 11.0.17+8-post-Ubuntu-1ubuntu218.04)
# OpenJDK 64-Bit Server VM (build 11.0.17+8-post-Ubuntu-1ubuntu218.04, mixed mode, sharing)

# %% [markdown]
# **2- Install SASPy**

# %%
# !pip install saspy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting saspy
#   Downloading saspy-4.4.0.tar.gz (9.9 MB)
#      |████████████████████████████████| 9.9 MB 4.4 MB/s
# Building wheels for collected packages: saspy
#   Building wheel for saspy (setup.py) ... done
#   Created wheel for saspy: filename=saspy-4.4.0-py3-none-any.whl size=9937189 sha256=58ce853e14732a85afe6e613016fbc56231f72b9b7a4b56503af28d50374fe33
#   Stored in directory: /root/.cache/pip/wheels/e7/67/b2/d95e4d2a4771d138cccfa28fb0814d94cf4f1548542c892412
# Successfully built saspy
# Installing collected packages: saspy
# Successfully installed saspy-4.4.0

# %% [markdown]
# **3- Create the configuration file "sascfg_personal.py"**
# Please, check that your Home Region is correct, you can check it at [ODA-SAS](https://welcome.oda.sas.com/home)

# %%
# %%writefile sascfg_personal.py
SAS_config_names=['oda']
oda = {'java' : '/usr/bin/java',
#US Home Region 1
#'iomhost' : ['odaws01-usw2.oda.sas.com','odaws02-usw2.oda.sas.com','odaws03-usw2.oda.sas.com','odaws04-usw2.oda.sas.com'],
#US Home Region 2
'iomhost' : ['odaws01-usw2-2.oda.sas.com','odaws02-usw2-2.oda.sas.com'],
#European Home Region 1
#'iomhost' : ['odaws01-euw1.oda.sas.com','odaws02-euw1.oda.sas.com'],
#Asia Pacific Home Region 1
#'iomhost' : ['odaws01-apse1.oda.sas.com','odaws02-apse1.oda.sas.com'],
#Asia Pacific Home Region 2
#'iomhost' : ['odaws01-apse1-2.oda.sas.com','odaws02-apse1-2.oda.sas.com'],
'iomport' : 8591,
'authkey' : 'oda',
'encoding' : 'utf-8'
}
# Out:
# Overwriting sascfg_personal.py

# %% [markdown]
# **4- Create your .authinfo**

# %% [markdown]
# If there is no .authinfo file, you can create this

# %%
#%%writefile .authinfo
#oda user a00827095@tec.mx password XXXXXX.

# %% [markdown]
# Copy this file to home

# %%
# !cp .authinfo ~/.authinfo

# %% [markdown]
# **5- Establish Connection (Need to do this step each time you use SASPy)**

# %%
import saspy
sas_session = saspy.SASsession(cfgfile="/content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS/sascfg_personal.py")
sas_session
# Out:
# Using SAS Config named: oda
# SAS Connection established. Subprocess id is 363
# Access Method         = IOM
# SAS Config name       = oda
# SAS Config file       = /content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS/sascfg_personal.py
# WORK Path             = /saswork/SAS_work7BD000003098_odaws02-usw2-2.oda.sas.com/SAS_work79F000003098_odaws02-usw2-2.oda.sas.com/
# SAS Version           = 9.04.01M6P11072018
# SASPy Version         = 4.4.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = utf-8
# Python Encoding value = utf-8
# SAS process Pid value = 12440

# %% [markdown]
# ***
# ## Connect to Cortex Data Sets

# %% [markdown]
# Load Cortex datasets from SAS Studio

# %%
ps = sas_session.submit("""
    libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';
    """)
print(ps["LOG"])
# Out:
# 5                                                          The SAS System                    Thursday, December  1, 2022 08:33:00 PM
#
# 24         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 24       ! ods graphics on / outputfmt=png;
# 25
# 26
# 27             libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';
# 28
# 29
# 30
# 31         ods html5 (id=saspy_internal) close;ods listing;
# 32
#
# 6                                                          The SAS System                    Thursday, December  1, 2022 08:33:00 PM
#
# 33

# %% [markdown]
# For local Jupyter

# %%
#%%SAS sas_session
#libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';

# %% [markdown]
# ## Transform cloud SAS dataset to Python dataframe (pandas)
#
#
# > **For reference**:
#
# > 1. [Pandas library](https://pandas.pydata.org/docs/user_guide/index.html)
#
# > 2. [sklearn.model_selection for data partition](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %%
import pandas as pd

data1 = sas_session.sasdata2dataframe(
table='hist',
libref='cortex'
)

data2 = sas_session.sasdata2dataframe(
table='target_rd1',
libref='cortex'
)

# %% [markdown]
# ## Merge the Data

# %%
data_merge = pd.merge(data1, data2, on=["ID"],how="right")
data_merge.sample(5)

#data_merge.head()
# Out:
#                ID   LastName FirstName  Woman   Age    Salary  \
# 351563  2351564.0  BERTOLONE   WILLIAM    0.0  78.0   10300.0
# 318123  2318124.0     OSTLER    ROBERT    0.0  26.0    1400.0
# 400034  2400035.0    YUSUPOV     CANDY    1.0  55.0   16600.0
# 215439  2215440.0  RODRIGUEZ    EDWARD    0.0  56.0    1900.0
# 49941   2049942.0   WILLIAMS    ROBERT    0.0  58.0  127500.0
#
#                    Education      City  SeniorList  NbActivities  ...  \
# 351563            Elementary      City         1.0           0.0  ...
# 318123  University / College      City         9.0           0.0  ...
# 400034           High School      City         8.0           0.0  ...
# 215439  University / College      City         8.0           1.0  ...
# 49941   University / College  Suburban         2.0           0.0  ...
#
#         Recency  Frequency  Seniority  TotalGift  MinGift  MaxGift  \
# 351563      NaN        NaN        NaN        NaN      NaN      NaN
# 318123      NaN        NaN        NaN        NaN      NaN      NaN
# 400034      NaN        NaN        NaN        NaN      NaN      NaN
# 215439      NaN        NaN        NaN        NaN      NaN      NaN
# 49941       NaN        NaN        NaN        NaN      NaN      NaN
#
#         GaveLastYear  AmtLastYear  GaveThisYear  AmtThisYear
# 351563           0.0          0.0           0.0          0.0
# 318123           0.0          0.0           0.0          0.0
# 400034           0.0          0.0           1.0         40.0
# 215439           0.0          0.0           0.0          0.0
# 49941            0.0          0.0           0.0          0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Treat Missing Values
#
# > Please be aware that deleting all missing values can induce a selection bias.
# Some missing values are very informative. For example, when MinGift is missing, it means that the donor never gave in the past 10 years (leading to but excluding last year). Instead of deleting this information, replacing it by 0 is more appropriate!
#
# > A good understanding of the business case and the data can help you come up with more appropriate strategies to deal with missing values.

# %%
# In this case, we are replacing MinGift by 0.
# You can do the same for what you think is reasonable for dealing with the other variables.

data_merge[['MinGift']] = data_merge[['MinGift']].fillna(value=0)  

data_merge.sample(3)
# Out:
#                ID LastName FirstName  Woman   Age   Salary  \
# 22997   2022998.0    BUGAI   CHARLES    0.0  57.0  58500.0
# 300732  2300733.0      KOY    JOSEPH    0.0  23.0   4600.0
# 56865   2056866.0    URIBE      RITA    1.0  72.0  35500.0
#
#                    Education   City  SeniorList  NbActivities  ...  Recency  \
# 22997            High School  Rural        10.0           6.0  ...      9.0
# 300732  University / College   City         7.0           1.0  ...      NaN
# 56865            High School  Rural         2.0           1.0  ...      1.0
#
#         Frequency  Seniority  TotalGift  MinGift  MaxGift  GaveLastYear  \
# 22997         2.0       10.0       55.0     25.0     30.0           0.0
# 300732        NaN        NaN        NaN      0.0      NaN           1.0
# 56865         2.0        2.0       20.0     10.0     10.0           1.0
#
#         AmtLastYear  GaveThisYear  AmtThisYear
# 22997           0.0           0.0          0.0
# 300732         15.0           0.0          0.0
# 56865          50.0           0.0          0.0
#
# [3 rows x 21 columns]

# %%
data_merge.isna().sum()
# Out:
# ID                   0
# LastName            23
# FirstName            4
# Woman                0
# Age                  0
# Salary               0
# Education            0
# City                 0
# SeniorList           0
# NbActivities         0
# Referrals            0
# Recency         663666
# Frequency       663666
# Seniority       663666
# TotalGift       663666
# MinGift              0
# MaxGift         663666
# GaveLastYear         0
# AmtLastYear          0
# GaveThisYear         0
# AmtThisYear          0
# dtype: int64

# %%
data_mergefloats = data_merge.loc[:, ~data_merge.columns.isin(['LastName', 'FirstName', 'Education', 'City'])]

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=3)

# %%
for i in data_mergefloats:
  data_mergefloats.loc[:,i]=imputer.fit_transform(data_mergefloats[[i]])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value

# %%
data_mergefloats.isna().sum()
# Out:
# ID              0
# Woman           0
# Age             0
# Salary          0
# SeniorList      0
# NbActivities    0
# Referrals       0
# Recency         0
# Frequency       0
# Seniority       0
# TotalGift       0
# MinGift         0
# MaxGift         0
# GaveLastYear    0
# AmtLastYear     0
# GaveThisYear    0
# AmtThisYear     0
# dtype: int64

# %%
data_mergefloats['City'] = data_merge['City']
data_mergefloats['Education'] = data_merge['Education']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Data Partition

# %%
# The code below is an illustration on how to sample data on train and validation samples.
# You could use another library or a built-in function to perform sampling.

from sklearn.model_selection import train_test_split
train, validation = train_test_split(data_merge, test_size=0.3, random_state=12345) 

#train.head()
train.sample(2)
# Out:
#                ID LastName FirstName  Woman   Age   Salary  \
# 251539  2251540.0      COX     FRANK    0.0  34.0  39500.0
# 776682  2776683.0   SALLAH    NATHAN    0.0  35.0  94100.0
#
#                    Education  City  SeniorList  NbActivities  ...  Recency  \
# 251539           High School  City         0.0           0.0  ...      NaN
# 776682  University / College  City         2.0           1.0  ...      NaN
#
#         Frequency  Seniority  TotalGift  MinGift  MaxGift  GaveLastYear  \
# 251539        NaN        NaN        NaN      0.0      NaN           0.0
# 776682        NaN        NaN        NaN      0.0      NaN           0.0
#
#         AmtLastYear  GaveThisYear  AmtThisYear
# 251539          0.0           1.0         20.0
# 776682          0.0           0.0          0.0
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Prebuilt Models
# ***

# %% [markdown]
# ## **XGBoost**

# %%
from xgboost import XGBRegressor
# read data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X_train = train[['Age', 'Salary','MinGift', 'AmtLastYear','Woman', 'NbActivities' ]] 
Y_train = train['AmtThisYear']
X_valid = validation[['Age', 'Salary','MinGift', 'AmtLastYear','Woman', 'NbActivities']] 
Y_valid = validation['AmtThisYear']
# create model instance
bst = XGBRegressor(n_estimators=1000, max_depth=10, learning_rate=0.01, objective='reg:linear')
# fit model
bst.fit(X_train, Y_train)
# make predictions
preds = bst.predict(X_valid)
# Out:
# [20:34:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-bb715ff1b02e> in <module>
#      11 bst = XGBRegressor(n_estimators=1000, max_depth=10, learning_rate=0.01, objective='reg:linear')
#      12 # fit model
# ---> 13 bst.fit(X_train, Y_train)
#      14 # make predictions
#      15 preds = bst.predict(X_valid)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.7/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
preds

# %%
#you can change the criteria
import numpy as np
from sklearn import metrics

#MAE
print(metrics.mean_absolute_error(Y_valid,preds))
#MSE
print(metrics.mean_squared_error(Y_valid,preds))
#RMSE
print(np.sqrt(metrics.mean_squared_error(Y_valid,preds)))

# %% [markdown]
# ## Scoring New Data
#
# ### Prepare data for scoring

# %%
data3 = sas_session.sasdata2dataframe(
table='score_rd1',
libref='cortex'
)
data4 = sas_session.sasdata2dataframe(
table='score',
libref='cortex'
)

# %% [markdown]
#  ### Score new data based on your champion model
#
# > Pick your champion model from previous steps and use it to predict next year donations.
#
# > In this case, the linear regression model performed better than the regression tree based on the MSE criterion.

# %%
scoring_data = pd.merge(data3, data4, on=["ID"],how="right")
scoring_datafloats = scoring_data.loc[:, ~scoring_data.columns.isin(['LastName', 'FirstName', 'Education', 'City'])]

# %%
# Perform the same strategy for handling missing values for the score dataset.
# In this case, we will only replace missing values of the MinGift variable.

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=2)

# %%
for i in scoring_datafloats:
  scoring_datafloats.loc[:,i]=imputer.fit_transform(scoring_datafloats[[i]])

#scoring_data[['MinGift']] = scoring_data[['MinGift']].fillna(value=0) 

scoring_datafloats.head()

# %%
scoring_datafloats['City'] = data_merge['City']
scoring_datafloats['Education'] = data_merge['Education']

# %%
# In this case, based on MSE (Mean Squared Error) criterion,
# the linear  regression model performed better than the regression tree.

X = scoring_datafloats[['Age', 'Salary','MinGift', 'AmtLastYear','Woman', 'NbActivities']] 
regressor_predict_predict_end= bst.predict(X)

scoring_datafloats['Prediction'] = regressor_predict_predict_end
scoring_datafloats.sort_values(by=['Prediction'], inplace=True,ascending=False)
scoring_datafloats.head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-303b6f3f84ff> in <module>
#       2 # the linear  regression model performed better than the regression tree.
#       3
# ----> 4 X = scoring_datafloats[['Age', 'Salary','MinGift', 'AmtLastYear','Woman', 'NbActivities']]
#       5 regressor_predict_predict_end= bst.predict(X)
#       6
#
# NameError: name 'scoring_datafloats' is not defined

# %% [markdown]
# ## Exporting Results to a CSV File

# %%
Result= scoring_datafloats[['ID']].astype(int)
#Result.to_csv('Round1_Output.csv', index=False)

# %%
# Define your cutoff and choose a number of rows to submit to the leaderboard
NB = 150000
submission = Result.head(NB)
submission.to_csv('Round1 Output.csv', index = False, header = False)

# %%
submission

# %%
# Reminder: Please note that you need only one column (the list of donors' IDs) to submit to the leaderboard.

# %%
# !head Round1\ Output.csv
