# %% [markdown]
# ![Python_logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
#
#
#  # **Cortex Game: Round2--Conditional Amount**
#
# Please note that you need to run this notebook 'Round2--Conditional Amount' first, before running the notebook 'Round2--Probability of Giving'.

# %% [markdown]
# > Before playing the game, you need to connect to SASPy first.
# >
# >> If it is your first time, please follow the 4 steps mentioned below!

# %% [markdown]
# ***
# ## **Connect to SASPy**

# %% [markdown]
# **0- Connect to your Google Drive folder**

# %%
my_folder = "/content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS"

from google.colab import drive
drive.mount('/content/drive')

# Change the following code to set your Drive folder
import os
os.chdir(my_folder)
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS

# %% [markdown]
# **1- Make sure that your Python version is 3.3 or higher as well as your Java version is 1.8.0_162 or higher**

# %%
# !echo "Python is at" $(which python)
# !python --version
# Out:
# Python is at /usr/local/bin/python
# Python 3.8.15

# %%
# !echo "Java is at" $(which java)
# !/usr/bin/java -version
# Out:
# Java is at /usr/bin/java
# openjdk version "11.0.17" 2022-10-18
# OpenJDK Runtime Environment (build 11.0.17+8-post-Ubuntu-1ubuntu218.04)
# OpenJDK 64-Bit Server VM (build 11.0.17+8-post-Ubuntu-1ubuntu218.04, mixed mode, sharing)

# %% [markdown]
# **2- Install SASPy**

# %%
pip install saspy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: saspy in /usr/local/lib/python3.8/dist-packages (4.4.0)

# %% [markdown]
# **3- Create the configuration file "sascfg_personal.py"**
# Please, check that your Home Region is correct, you can check it at [ODA-SAS](https://welcome.oda.sas.com/home)

# %%
# %%writefile sascfg_personal.py
SAS_config_names=['oda']
oda = {'java' : '/usr/bin/java',
#US Home Region 1
#'iomhost' : ['odaws01-usw2.oda.sas.com','odaws02-usw2.oda.sas.com','odaws03-usw2.oda.sas.com','odaws04-usw2.oda.sas.com'],
#US Home Region 2
'iomhost' : ['odaws01-usw2-2.oda.sas.com','odaws02-usw2-2.oda.sas.com'],
#European Home Region 1
#'iomhost' : ['odaws01-euw1.oda.sas.com','odaws02-euw1.oda.sas.com'],
#Asia Pacific Home Region 1
#'iomhost' : ['odaws01-apse1.oda.sas.com','odaws02-apse1.oda.sas.com'],
#Asia Pacific Home Region 2
#'iomhost' : ['odaws01-apse1-2.oda.sas.com','odaws02-apse1-2.oda.sas.com'],
'iomport' : 8591,
'authkey' : 'oda',
'encoding' : 'utf-8'
}
# Out:
# Overwriting sascfg_personal.py

# %% [markdown]
# **4- Create your .authinfo**

# %% [markdown]
# If there is no .authinfo file, you can create this

# %%
#%%writefile .authinfo
#oda user USR password PSW

# %% [markdown]
# Copy this file to home

# %%
# !cp .authinfo ~/.authinfo

# %% [markdown]
# **5- Establish Connection (Need to do this step each time you use SASPy)**

# %%
import saspy
sas_session = saspy.SASsession(cfgfile=os.path.join(
    my_folder,"sascfg_personal.py"))
sas_session
# Out:
# Using SAS Config named: oda
# SAS Connection established. Subprocess id is 1061
# Access Method         = IOM
# SAS Config name       = oda
# SAS Config file       = /content/drive/MyDrive/Semestre7/InteligenciaArtificial2/RetoSAS/sascfg_personal.py
# WORK Path             = /saswork/SAS_workE47200008DC7_odaws01-usw2-2.oda.sas.com/SAS_workA27400008DC7_odaws01-usw2-2.oda.sas.com/
# SAS Version           = 9.04.01M6P11072018
# SASPy Version         = 4.4.0
# Teach me SAS          = False
# Batch                 = False
# Results               = Pandas
# SAS Session Encoding  = utf-8
# Python Encoding value = utf-8
# SAS process Pid value = 36295

# %% [markdown]
# ***
# ## Connect to Cortex Data Sets

# %% [markdown]
# Load Cortex datasets from SAS Studio

# %%
ps = sas_session.submit("""
    libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';
    """)
print(ps["LOG"])
# Out:
# 5                                                          The SAS System                    Thursday, December  1, 2022 09:58:00 PM
#
# 24         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 24       ! ods graphics on / outputfmt=png;
# 25
# 26
# 27             libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';
# 28
# 29
# 30
# 31         ods html5 (id=saspy_internal) close;ods listing;
# 32
#
# 6                                                          The SAS System                    Thursday, December  1, 2022 09:58:00 PM
#
# 33

# %% [markdown]
# For local Jupyter

# %%
#%%SAS sas_session
#libname cortex '~/my_shared_file_links/u39842936/Cortex Data Sets';

# %% [markdown]
# ### Transform cloud SAS dataset to Python dataframe (pandas)
#
# > For reference:
#
# > 1- [Pandas library](https://pandas.pydata.org/docs/user_guide/index.html)
#
# > 2- [sklearn.model_selection for data partition](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %%
import pandas as pd

#comment: Transform cloud sas dataset to python dataframe(pandas) ==> might take some time.

data1 = sas_session.sasdata2dataframe(
table='hist',
libref='cortex'
)

data2 = sas_session.sasdata2dataframe(
table='target_rd2',
libref='cortex'
)

# %% [markdown]
# ## Merge the Data

# %%
#Step1 Merge the Data
data_merge = pd.merge(data1, data2, on=["ID"],how="right")
data_merge = data_merge.loc[(data_merge['GaveThisYear'] ==1)]
data_merge.sample(2)
# Out:
#                ID  LastName FirstName  Woman   Age    Salary  \
# 520415  2520416.0  LASSITER   JOHNNIE    0.0  49.0   39600.0
# 848487  2848488.0    SHARPE   VALERIA    1.0  20.0  105000.0
#
#                    Education      City  SeniorList  NbActivities  ...  \
# 520415  University / College  Suburban         0.0           0.0  ...
# 848487  University / College      City         5.0           2.0  ...
#
#         Frequency  Seniority  TotalGift  MinGift  MaxGift  GaveLastYear  \
# 520415        NaN        NaN        NaN      NaN      NaN           0.0
# 848487        2.0        4.0       70.0     20.0     50.0           0.0
#
#         AmtLastYear  Contact  GaveThisYear  AmtThisYear
# 520415          0.0      0.0           1.0         20.0
# 848487          0.0      0.0           1.0         40.0
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Treating Missing Values
#
# >Please be aware that deleting all missing values can induce a selection bias.
# Some missing values are very informative. For example, when MinGift is missing, it means that the donor never gave in the past 10 years (leading to but excluding last year). Instead of deleting this information, replacing it by 0 is more appropriate!
#
# > A good understanding of the business case and the data can help you come up with more appropriate strategies to deal with missing values.

# %%
data_mergefloats = data_merge.loc[:, ~data_merge.columns.isin(['LastName', 'FirstName', 'Education', 'City'])]

# %%
# In this case, we are replacing MinGift by 0.
# You can do the same for what you think is reasonable for dealing with the other variables.
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imputer = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=3)

# %%
for i in data_mergefloats:
  data_mergefloats.loc[:,i]=imputer.fit_transform(data_mergefloats[[i]])
data_mergefloats = data_mergefloats.sort_index()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value

# %%
data_mergefloats.head(10)
# Out:
#            ID  Woman   Age    Salary  SeniorList  NbActivities  Referrals  \
# 3   2000004.0    1.0  78.0   23700.0         3.0           0.0        0.0
# 7   2000008.0    0.0  30.0   92700.0         2.0           0.0        0.0
# 11  2000012.0    1.0  52.0   77600.0         0.0           0.0        0.0
# 16  2000017.0    1.0  50.0   13000.0         0.0           0.0        0.0
# 20  2000021.0    1.0  39.0  237800.0         5.0           0.0        0.0
# 23  2000024.0    0.0  27.0   20900.0        10.0           1.0        1.0
# 34  2000035.0    1.0  31.0   46500.0         0.0           0.0        0.0
# 38  2000039.0    0.0  38.0  179400.0         5.0           0.0        0.0
# 39  2000040.0    1.0  36.0   17300.0         0.0           0.0        0.0
# 40  2000041.0    1.0  42.0   99000.0         6.0           1.0        1.0
#
#     Recency  Frequency  Seniority   TotalGift    MinGift     MaxGift  \
# 3   2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 7   2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 11  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 16  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 20  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 23  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 34  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 38  4.00000   1.000000   4.000000   50.000000  50.000000   50.000000
# 39  2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 40  4.00000   2.000000   5.000000  175.000000  25.000000  150.000000
#
#     GaveLastYear  AmtLastYear  Contact  GaveThisYear  AmtThisYear
# 3            0.0          0.0      1.0           1.0         20.0
# 7            0.0          0.0      1.0           1.0         30.0
# 11           0.0          0.0      1.0           1.0         20.0
# 16           1.0         20.0      1.0           1.0         75.0
# 20           0.0          0.0      1.0           1.0         20.0
# 23           0.0          0.0      1.0           1.0         10.0
# 34           0.0          0.0      1.0           1.0         25.0
# 38           0.0          0.0      0.0           1.0         40.0
# 39           0.0          0.0      0.0           1.0         25.0
# 40           0.0          0.0      1.0           1.0        100.0

# %%
data_mergefloats['City'] = data_merge['City']
data_mergefloats['Education'] = data_merge['Education']

# %% [markdown]
# ## Data Partition

# %%
# The code below is an illustration on how to sample data on train and validation samples.
# You could use another library or a built-in function to perform sampling.

from sklearn.model_selection import train_test_split
train, validation = train_test_split(data_mergefloats, test_size=0.3,random_state=5678) # you can change the percentage
train.sample(5)
# Out:
#                ID  Woman   Age   Salary  SeniorList  NbActivities  Referrals  \
# 422986  2422987.0    0.0  73.0  19600.0         1.0           0.0        0.0
# 104541  2104542.0    1.0  37.0  12900.0        10.0           2.0        0.0
# 683286  2683287.0    0.0  67.0  22400.0         0.0           0.0        0.0
# 508658  2508659.0    1.0  54.0  36200.0         5.0           3.0        0.0
# 377220  2377221.0    0.0  46.0  69000.0         0.0           0.0        0.0
#
#          Recency  Frequency  Seniority   TotalGift    MinGift     MaxGift  \
# 422986   2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 104541  10.00000   1.000000  10.000000   20.000000  20.000000   20.000000
# 683286   2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
# 508658   5.00000   1.000000   5.000000   30.000000  30.000000   30.000000
# 377220   2.75091   1.985796   4.674952  134.864685  42.502521  106.674485
#
#         GaveLastYear  AmtLastYear  Contact  GaveThisYear  AmtThisYear  \
# 422986           1.0         10.0      0.0           1.0         20.0
# 104541           1.0         30.0      0.0           1.0         20.0
# 683286           1.0         30.0      0.0           1.0         10.0
# 508658           0.0          0.0      1.0           1.0         50.0
# 377220           0.0          0.0      0.0           1.0         75.0
#
#             City             Education
# 422986      City  University / College
# 104541  Suburban  University / College
# 683286  Suburban  University / College
# 508658      City           High School
# 377220  Suburban           High School

# %% [markdown]
# ## Prebuilt Models
#
# ***

# %% [markdown]
# ### **XGBoost**

# %%
from xgboost import XGBRegressor
# read data
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

X_train = train[['Age', 'Salary','Contact','MinGift', 'GaveLastYear','AmtLastYear','Woman', 'NbActivities' ]] 
Y_train = train['AmtThisYear']
X_valid = validation[['Age', 'Salary','Contact','MinGift', 'GaveLastYear','AmtLastYear','Woman', 'NbActivities']] 
Y_valid = validation['AmtThisYear']
# create model instance
bst = XGBRegressor(n_estimators=1000, max_depth=10, learning_rate=0.01, objective='reg:linear')
# fit model
bst.fit(X_train, Y_train)
# make predictions
preds = bst.predict(X_valid)
# Out:
# [21:58:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
preds
# Out:
# array([ 56.23345 ,  26.238762, 155.18205 , ...,  37.082386,  54.120457,
#         56.829544], dtype=float32)

# %%
import numpy as np
from sklearn import metrics
#you can change the criteria
#MAE
print(metrics.mean_absolute_error(Y_valid,preds))
#MSE
print(metrics.mean_squared_error(Y_valid,preds))
#RMSE
print(np.sqrt(metrics.mean_squared_error(Y_valid,preds)))
# Out:
# 66.34485552314825
# 60394.48925137592
# 245.75290283407827

# %% [markdown]
# ## Scoring New Data
#
# ### Prepare data for scoring

# %%
data3 = sas_session.sasdata2dataframe(
table='score',
libref='cortex'
)
data4 = sas_session.sasdata2dataframe(
table='score_rd2_contact',
libref='cortex'
)
data5 = sas_session.sasdata2dataframe(
table='score_rd2_nocontact',
libref='cortex'
)

# %% [markdown]
#  ### Score new data based on your champion model
#
#  Pick your champion model from previous steps and use it to predict next year donations.
#
#  In this case, the linear regression model performed better than the regression tree based on the MSE criteria.

# %% [markdown]
# ### Predict 'amount given' for members who were contacted

# %%
scoring_data_contact = pd.merge(data3, data4, on=["ID"],how="right")

# Perform the same strategy for handling missing values for the score dataset.
# In this case, we will only replace missing values of the MinGift variable.

scoring_data_contact[['MinGift']] = scoring_data_contact[['MinGift']].fillna(value=0) 

#scoring_data_contact.head()

X = scoring_data_contact[['Age', 'Salary', 'Contact', 'MinGift','GaveLastYear','AmtLastYear', 'Woman', 'NbActivities' ]] 

preds_predict_contact=bst.predict(X)

scoring_data_contact['Prediction'] = preds_predict_contact

scoring_data_contact= scoring_data_contact[['ID','Prediction']]
scoring_data_contact = scoring_data_contact.rename({'Prediction': 'AmtContact'}, axis=1) 
scoring_data_contact.head()
# Out:
#           ID  AmtContact
# 0  2000001.0   78.308823
# 1  2000002.0   59.129337
# 2  2000003.0  178.444672
# 3  2000004.0   36.540581
# 4  2000005.0   64.036926

# %% [markdown]
# ### Predict 'amount given' for members who were not contacted

# %%
scoring_data_nocontact = pd.merge(data3, data5, on=["ID"],how="right")

# Perform the same strategy for handling missing values for the score dataset.
# In this case, we will only replace missing values of the MinGift variable.

scoring_data_nocontact[['MinGift']] = scoring_data_nocontact[['MinGift']].fillna(value=0)

#scoring_data_nocontact.head()

X = scoring_data_nocontact[['Age', 'Salary', 'Contact', 'MinGift','GaveLastYear','AmtLastYear', 'Woman', 'NbActivities'  ]] 

preds_predict_nocontact=bst.predict(X)

scoring_data_nocontact['Prediction'] = preds_predict_nocontact

scoring_data_nocontact= scoring_data_nocontact[['ID','Prediction']]
scoring_data_nocontact = scoring_data_nocontact.rename({'Prediction': 'AmtNoContact'}, axis=1) 
scoring_data_nocontact.head()
# Out:
#           ID  AmtNoContact
# 0  2000001.0     16.957851
# 1  2000002.0     55.251312
# 2  2000003.0    192.672821
# 3  2000004.0     38.491028
# 4  2000005.0    102.298172

# %%
result_Amt = pd.merge(scoring_data_contact, scoring_data_nocontact, on=["ID"],how="right")
result_Amt.sort_values(by=['ID'], inplace=True)
result_Amt.head(3)
# Out:
#           ID  AmtContact  AmtNoContact
# 0  2000001.0   78.308823     16.957851
# 1  2000002.0   59.129337     55.251312
# 2  2000003.0  178.444672    192.672821

# %% [markdown]
# ## Exporting Results to a CSV File

# %%
result_Amt.to_csv('Round2_Output_amt.csv', index=False)

# %%
# Reminder: You are now done with step 1 of Round 2 on predicting the conditional amount.
# Next, to complete Round2, you need to perform step 2 to predict the probability of giving, calculate the uplift and prepare your decision.

# %%
# !head Round2_Output_amt.csv
# Out:
# ID,AmtContact,AmtNoContact
# 2000001.0,78.30882,16.957851
# 2000002.0,59.129337,55.251312
# 2000003.0,178.44467,192.67282
# 2000004.0,36.54058,38.491028
# 2000005.0,64.03693,102.29817
# 2000006.0,47.649815,43.868923
# 2000007.0,23.22694,25.919353
# 2000008.0,47.665188,50.80959
# 2000009.0,36.82227,37.019146
